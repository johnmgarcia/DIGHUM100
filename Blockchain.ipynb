# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
btc_active_user = pd.read_csv("active-addresses_csv.csv")
uni_tx = pd.read_csv("uniswap-transactions.csv")
btc_hash_rate = pd.read_csv("hash-rate.csv")

# %%
uni_tx_table = pd.read_table("uniswap-transactions.csv")
btc_hr_table = pd.read_table("hash-rate.csv")
btc_active_table = pd.read_table("active-addresses_csv.csv")

# %%
# %ls
# Out:
#  Volume in drive C is X
#  Volume Serial Number is 3845-C00A
#
#  Directory of C:\Users\JM\Desktop\glassnode
#
# 06/20/2021  09:16 PM    <DIR>          .
# 06/20/2021  09:16 PM    <DIR>          ..
# 06/20/2021  05:24 PM    <DIR>          .ipynb_checkpoints
# 06/20/2021  04:37 PM           146,368 active-addresses_csv.csv
# 06/20/2021  05:07 PM               489 futures-open-interest-current.csv
# 06/20/2021  07:25 PM           204,237 hash-rate.csv
# 06/20/2021  07:24 PM           236,048 hash-rate.json
# 06/20/2021  05:33 PM             5,149 project.ipynb
# 06/20/2021  08:11 PM            11,807 uniswap-transactions.csv
# 06/20/2021  06:41 PM            16,318 uniswap-transactions.json
# 06/20/2021  09:16 PM            13,263 Untitled.ipynb
#                8 File(s)        633,679 bytes
#                3 Dir(s)  34,643,603,456 bytes free

# %%
#btc_active users
xbtc = np.array(btc_active_user[['t']])
ybtc = np.array(btc_active_user[['v']])
line = plt.plot(btc_active_user.v)
line

# %%
uni_tx_table
# Out:
#                date,transactions
# 0         2020-05-05T00:00:00Z,3
# 1         2020-05-06T00:00:00Z,5
# 2         2020-05-07T00:00:00Z,2
# 3         2020-05-08T00:00:00Z,8
# 4         2020-05-09T00:00:00Z,0
# ..                           ...
# 407  2021-06-16T00:00:00Z,153768
# 408  2021-06-17T00:00:00Z,160849
# 409  2021-06-18T00:00:00Z,147916
# 410  2021-06-19T00:00:00Z,158647
# 411  2021-06-20T00:00:00Z,147859
#
# [412 rows x 1 columns]

# %%
#hash rate
xhash = np.array(btc_hash_rate[['t']])
yhash = np.array(btc_hash_rate[['v']])
lineHash = plt.plot(btc_hash_rate.v)
lineHash

# %%
#uni_tx_table
xuni = np.array(uni_tx[['date']])
yuni = np.array(uni_tx[['transactions']])
lineUnitx = plt.plot(uni_tx.transactions)
#lineUnitx
#line_uni = plt.plot(xuni,yuni)

# %%
plt.scatter(uni_tx.date,uni_tx.transactions)
